# %% [markdown]
# ## Extration Feature
# @created_at: 17 Sept 2023
# <hr/>

# %% [markdown]
# #### Introduction

# %% [markdown]
# ##### Load Dataset

# %%
import pandas as pd

dataset = pd.read_csv('result/feature_extraction_0_deg.csv')

# %% [markdown]
# #### Skala0

# %%
dataset[dataset.target==0].head(10)
# Out:
#    contrast_0  homogeneity_0  correlation_0  energy_0      h_mean     s_mean  \
# 0  145.339246       0.850462       0.834026  0.169013  102.019578   6.076716
# 1  184.509526       0.813971       0.917925  0.173206  107.860592  49.071800
# 2  220.024115       0.805244       0.862426  0.135212  107.707690  42.995309
# 3  360.124997       0.793118       0.774049  0.204921  111.507190  21.193654
# 4  139.916641       0.775964       0.838576  0.162431  108.038949  60.611979
# 5  230.512979       0.778215       0.881520  0.163700  106.808220  59.647382
# 6  234.960332       0.784408       0.880444  0.130162  107.996451  29.738549
# 7  253.683278       0.878501       0.858032  0.191643  113.056509  21.169357
# 8  288.414027       0.816776       0.855797  0.133567  109.892129  19.040806
# 9  314.616734       0.878171       0.807569  0.202048  114.022731  23.685361
#
#        v_mean  target   label
# 0  239.601118       0  Skala0
# 1  219.021018       0  Skala0
# ...

# %% [markdown]
# #### Skala1

# %%
dataset[dataset.target==1].head(10)
# Out:
#     contrast_0  homogeneity_0  correlation_0  energy_0      h_mean     s_mean  \
# 29  277.272654       0.845977       0.798778  0.173240  113.176831  28.754019
# 30  331.302901       0.851147       0.737020  0.238628  109.001161  26.377258
# 31  191.499244       0.762596       0.858332  0.093861  112.595070  22.671019
# 32  150.514764       0.841574       0.777871  0.374956   36.145684   7.879730
# 33  195.137062       0.819536       0.871868  0.217074  106.029557  25.848501
# 34  241.861363       0.784017       0.701888  0.180523  111.551107  15.319124
# 35  282.811068       0.791534       0.779567  0.141793  108.058223  20.245738
# 36  252.001261       0.836700       0.676339  0.226702  110.494231  22.442039
# 37  168.538669       0.791286       0.861490  0.135580   99.001630  38.043648
# 38  267.709699       0.768359       0.793599  0.112127  107.994468  50.346874
#
#         v_mean  target   label
# 29  229.992928       1  Skala1
# 30  238.242874       1  Skala1
# ...

# %% [markdown]
# #### Skala2

# %%
dataset[dataset.target==2].head(10)
# Out:
#     contrast_0  homogeneity_0  correlation_0  energy_0      h_mean     s_mean  \
# 59  312.151349       0.940729       0.848122  0.925213    6.010853   3.653644
# 60  258.336412       0.901128       0.739370  0.335779   98.672328   5.678946
# 61  186.029939       0.837223       0.838663  0.180490  108.501840  16.891071
# 62  181.181899       0.911849       0.841983  0.383004  109.796222  20.610278
# 63  284.910970       0.794091       0.798159  0.121346  109.168253  41.313189
# 64  143.248944       0.789957       0.870154  0.104658  109.172545  21.188661
# 65  360.216263       0.865740       0.787149  0.263600  111.715121  19.911313
# 66   96.560750       0.822353       0.922863  0.215066   86.646729  22.645258
# 67  205.839794       0.856898       0.835033  0.236312   86.438248  11.561203
# 68  429.557183       0.809361       0.722319  0.166506  110.352660  17.498975
#
#         v_mean  target   label
# 59  249.349015       2  Skala2
# 60  250.216931       2  Skala2
# ...

# %% [markdown]
# #### Skala3

# %%
dataset[dataset.target==3].head(10)
# Out:
#     contrast_0  homogeneity_0  correlation_0  energy_0      h_mean     s_mean  \
# 89  118.385748       0.893818       0.851295  0.321830   77.087818   4.661826
# 90  316.398484       0.853556       0.829570  0.352523   76.454418   7.866705
# 91  198.531713       0.844855       0.773028  0.255439   93.503071  15.465868
# 92  243.468753       0.897685       0.830352  0.336127  100.310883   8.496220
# 93  193.451311       0.903444       0.819943  0.362500  109.842337  13.467452
# 94  278.789299       0.758077       0.827197  0.164240  104.328014  23.998804
# 95  154.736183       0.809863       0.859266  0.167975  104.774505  14.693995
# 96  313.785540       0.887200       0.701916  0.415785   97.271489   6.526691
# 97  162.611693       0.830883       0.833234  0.239905   95.329743   9.164923
# 98  176.143285       0.890647       0.732908  0.272347  108.212417  10.982186
#
#         v_mean  target   label
# 89  247.228214       3  Skala3
# 90  247.217495       3  Skala3
# ...

# %% [markdown]
# #### Skala4

# %%
dataset[dataset.target==4].head(10)
# Out:
#      contrast_0  homogeneity_0  correlation_0  energy_0      h_mean  \
# 120  163.851471       0.839627       0.690030  0.216348  111.291986
# 121   66.880574       0.695161       0.903473  0.245589   82.925994
# 122  193.793053       0.740792       0.738278  0.129822  107.952250
# 123   71.536553       0.893461       0.841961  0.258095  103.360788
# 124  235.063035       0.809556       0.921289  0.162790  103.935949
# 125   62.394334       0.866097       0.889195  0.240455   91.519547
# 126  197.001979       0.841066       0.851847  0.241958  106.259523
# 127  171.827459       0.784244       0.871065  0.196828  106.157886
# 128  138.816432       0.762415       0.889232  0.170832  109.003166
# 129   94.536842       0.922463       0.865184  0.350638  108.809934
#
#         s_mean      v_mean  target   label
# 120  21.983584  225.783867       4  Skala4
# 121  13.028479  245.860749       4  Skala4
# 122  49.472471  214.406960       4  Skala4
# 123  10.086218  252.667714       4  Skala4
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df0 = dataset[:30]
df1 = dataset[30:60]
df2 = dataset[60:90]
df3 = dataset[90:120]
df4 = dataset[120:150]

plt.figure(figsize=(15,7))
plt.scatter(df0['contrast_0'], df0['homogeneity_0'], df0['correlation_0'], df0['energy_0'], marker='.',label='Skala0')
plt.scatter(df1['contrast_0'], df1['homogeneity_0'], df1['correlation_0'], df1['energy_0'], marker=',',label='Skala1')
plt.scatter(df2['contrast_0'], df2['homogeneity_0'], df2['correlation_0'], df2['energy_0'], marker='o',label='Skala2')
plt.scatter(df3['contrast_0'], df3['homogeneity_0'], df3['correlation_0'], df3['energy_0'], marker='v',label='Skala3')
plt.scatter(df4['contrast_0'], df4['homogeneity_0'], df4['correlation_0'], df4['energy_0'], marker='p',label='Skala4')
plt.legend()
plt.show()

# %% [markdown]
# #### Splitting Data

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop(['target', 'label'], axis='columns')
y = dataset.target

X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=3)

# %%
X_train.shape, y_train.shape
# Out:
# ((120, 7), (120,))

# %%
X_test.shape, y_test.shape
# Out:
# ((30, 7), (30,))

# %% [markdown]
# #### Create K Nearest Neighbor Classification (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=8)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
X_test
# Out:
#      contrast_0  homogeneity_0  correlation_0  energy_0      h_mean  \
# 47   295.628197       0.794730       0.797347  0.132476  118.800496
# 3    360.124997       0.793118       0.774049  0.204921  111.507190
# 31   191.499244       0.762596       0.858332  0.093861  112.595070
# 25   342.882658       0.778234       0.802913  0.160043  112.766956
# 15   290.221240       0.800694       0.821511  0.145396  115.066169
# 118  238.908737       0.814302       0.787977  0.166972  103.968933
# 89   118.385748       0.893818       0.851295  0.321830   77.087818
# 6    234.960332       0.784408       0.880444  0.130162  107.996451
# 103  221.930243       0.832561       0.786376  0.292519  108.175533
# 65   360.216263       0.865740       0.787149  0.263600  111.715121
# 88   132.506885       0.890686       0.867457  0.265934  110.563849
# 38   267.709699       0.768359       0.793599  0.112127  107.994468
# 92   243.468753       0.897685       0.830352  0.336127  100.310883
# ...

# %%
knn.score(X_test, y_test)
# Out:
# 0.36666666666666664

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
y_pred=knn.predict(X_test)
matrix= confusion_matrix(y_test, y_pred)  #  confusion_matrix(truth, prediction)
matrix
# Out:
# array([[4, 0, 0, 0, 1],
#        [6, 1, 0, 0, 0],
#        [1, 0, 2, 3, 0],
#        [1, 2, 2, 2, 0],
#        [2, 0, 1, 0, 2]], dtype=int64)

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(matrix, annot= True)
plt.xlabel('predict')
plt.ylabel('truth')
# Out:
# Text(95.72222222222221, 0.5, 'truth')

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import classification_report
print( classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.80      0.42         5
#            1       0.33      0.14      0.20         7
#            2       0.40      0.33      0.36         6
#            3       0.40      0.29      0.33         7
#            4       0.67      0.40      0.50         5
#
#     accuracy                           0.37        30
#    macro avg       0.42      0.39      0.36        30
# weighted avg       0.41      0.37      0.35        30
